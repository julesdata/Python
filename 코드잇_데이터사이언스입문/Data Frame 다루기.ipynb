# %% [markdown]
# # Data Frame 인덱싱

# %%
import pandas as pd

# %%
iphone_df = pd.read_csv('../../../../../Downloads/iphone.csv', index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
#iphone_df = pd.read_csv('../../../../Downloads/iphone.csv', index_col=0)
#iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# ## 로우와 컬럼의 이름으로 가져오기(라벨 인덱싱 loc)
# ### 인덱싱
# * .loc['행이름','열이름']

# %%
iphone_df.loc['iPhone 8','메모리']
# Out:
# '2GB'

# %% [markdown]
# * 하나의 row 이름 : 행 전체 가져오기

# %%
iphone_df.loc['iPhone X', :]
# Out:
# 출시일        2017-11-03
# 디스플레이             5.8
# 메모리               3GB
# 출시 버전        iOS 11.1
# Face ID           Yes
# Name: iPhone X, dtype: object

# %%
iphone_df.loc['iPhone X']
# Out:
# 출시일        2017-11-03
# 디스플레이             5.8
# 메모리               3GB
# 출시 버전        iOS 11.1
# Face ID           Yes
# Name: iPhone X, dtype: object

# %%
type(iphone_df.loc['iPhone X'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# * 하나의 colum 이름: 컬럼 전체 가져오기

# %%
#기본형태
iphone_df.loc[:,'출시일']
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %% [markdown]
# * loc없이 컬럼명을 바로 인덱싱할 수 있다.
#   df.loc[:"col1"])의 단축형 -> df["col1"]

# %%
#단축 형태
iphone_df['출시일']
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %%
type(iphone_df['출시일'])

# 인덱스 없이 값들만 가져오는 시리즈형태로 반환된다.
# Out:
# pandas.core.series.Series

# %% [markdown]
# * 여러 행 또는 열 가져오기 : 여러개의 로우 또는 컬럼명을 리스트로 넣어준다.

# %%
# row이름의 리스트
iphone_df.loc[['iPhone X', 'iPhone 7']]
# Out:
#                  출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone X  2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone 7  2016-09-16    4.7  2GB  iOS 10.0      No

# %%
# column이름의 리스트 
iphone_df.loc[:,['출시일','메모리']]
# Out:
#                       출시일  메모리
# iPhone 7       2016-09-16  2GB
# iPhone 7 Plus  2016-09-16  3GB
# iPhone 8       2017-09-22  2GB
# iPhone 8 Plus  2017-09-22  3GB
# iPhone X       2017-11-03  3GB
# iPhone XS      2018-09-21  4GB
# iPhone XS Max  2018-09-21  4GB

# %%
# column이름의 리스트 단축형
iphone_df[['출시일','메모리']]
# Out:
#                       출시일  메모리
# iPhone 7       2016-09-16  2GB
# iPhone 7 Plus  2016-09-16  3GB
# iPhone 8       2017-09-22  2GB
# iPhone 8 Plus  2017-09-22  3GB
# iPhone X       2017-11-03  3GB
# iPhone XS      2018-09-21  4GB
# iPhone XS Max  2018-09-21  4GB

# %% [markdown]
# ### 슬라이싱
# 이름으로 슬라이싱 할 때는 지정한 곳 까지 전부 출력된다. (이전 행까지 아님. 지정행 포함)
# * 행 슬라이싱

# %%
#기본형 : df.loc["row2":"row5"]
iphone_df.loc['iPhone 8': 'iPhone XS']
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes

# %%
# 단축형 : df["row2":"row5"]
iphone_df['iPhone 8': 'iPhone XS']
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes

# %% [markdown]
# * 열 슬라이싱

# %%
#loc 없이는 불가능하다. 단축형 없음
iphone_df['출시일':'메모리']
# Out:
# Empty DataFrame
# Columns: [출시일, 디스플레이, 메모리, 출시 버전, Face ID]
# Index: []

# %%
iphone_df.loc[:,'출시일':'메모리']
# Out:
#                       출시일  디스플레이  메모리
# iPhone 7       2016-09-16    4.7  2GB
# iPhone 7 Plus  2016-09-16    5.5  3GB
# iPhone 8       2017-09-22    4.7  2GB
# iPhone 8 Plus  2017-09-22    5.5  3GB
# iPhone X       2017-11-03    5.8  3GB
# iPhone XS      2018-09-21    5.8  4GB
# iPhone XS Max  2018-09-21    6.5  4GB

# %% [markdown]
# ## DataFrame 조건으로 인덱싱
# ### 불린리스트 직접입력
# 행,열 갯수에 맞는 리스트 요소를 모두 적어줘야한다.

# %%
iphone_df.loc[[True,False,True,True,False,True,False]] #0,2,3,5 번 행만 반환
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes

# %%
iphone_df[[True,False,True,True,False,True,False]] #loc없이 가능
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes

# %%
iphone_df.loc[:,[True,False,False,True,True]]
# Out:
#                       출시일     출시 버전 Face ID
# iPhone 7       2016-09-16  iOS 10.0      No
# iPhone 7 Plus  2016-09-16  iOS 10.0      No
# iPhone 8       2017-09-22  iOS 11.0      No
# iPhone 8 Plus  2017-09-22  iOS 11.0      No
# iPhone X       2017-11-03  iOS 11.1     Yes
# iPhone XS      2018-09-21  iOS 12.0     Yes
# iPhone XS Max  2018-09-21  iOS 12.0     Yes

# %%
iphone_df[:,[True,False,False,True,True]] #loc없이 불가능
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-910f44d12809> in <module>
# ----> 1 iphone_df[:,[True,False,False,True,True]] #loc없이 불가능
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2893             casted_key = self._maybe_cast_indexer(key)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#    2897                 raise KeyError(key) from err
#
# ...

# %% [markdown]
# ### 결과를 불린으로 나타낼수 있는 조건 입력

# %%
iphone_df['디스플레이']>5
# 디스플레이 열에서, 값이 5 이상인지 여부가 시리즈로 반환된다.
# Out:
# iPhone 7         False
# iPhone 7 Plus     True
# iPhone 8         False
# iPhone 8 Plus     True
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: 디스플레이, dtype: bool

# %%
# 인덱스에 대한 T/F가 반환되므로 이 조건문을 불린결과 대신 입력할 수 있다. 
iphone_df.loc[iphone_df['디스플레이']>5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
#loc없이 가능 
iphone_df[iphone_df['디스플레이']>5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# ## DataFrame 위치로 인덱싱하기
# * iloc : integer-location
# * df.iloc[행번호, 열번호]

# %%
iphone_df.iloc[2,4]
# Out:
# 'No'

# %%
# 여러 값 가져오기 : 로우리스트, 컬럼리스트
iphone_df.iloc[[1,3],[1,4]]
# Out:
#                디스플레이 Face ID
# iPhone 7 Plus    5.5      No
# iPhone 8 Plus    5.5      No

# %%
#연속된 인덱싱
iphone_df.iloc[3:, 1:4]
# Out:
#                디스플레이  메모리     출시 버전
# iPhone 8 Plus    5.5  3GB  iOS 11.0
# iPhone X         5.8  3GB  iOS 11.1
# iPhone XS        5.8  4GB  iOS 12.0
# iPhone XS Max    6.5  4GB  iOS 12.0

# %%
# 행만 가져오기
iphone_df.iloc[2]
# Out:
# 출시일        2017-09-22
# 디스플레이             4.7
# 메모리               2GB
# 출시 버전        iOS 11.0
# Face ID            No
# Name: iPhone 8, dtype: object

# %%
#행 슬라이싱
iphone_df.iloc[2:5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes

# %% [markdown]
# * loc, iloc모두 슬라이싱에서는 행 슬라이싱만 단축 가능하다.

# %%
# 행 슬라이싱 단축: iloc생략
iphone_df[2:5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes

# %% [markdown]
# # 데이터 변형하기
# ## DagaFrame에 값 쓰기1

# %%
iphone_df.loc['iPhone 8', '메모리']
# Out:
# '2GB'

# %% [markdown]
# ### 특정 행,열에 값 쓰기

# %%
# 새로운 값을 할당하면 그 값이 새로운 값이 된다. 
iphone_df.loc['iPhone 8', '메모리'] = '2.5BG'

# %%
iphone_df
# Out:
#                       출시일  디스플레이    메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7    2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5    3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2.5BG  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5    3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8    3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8    4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5    4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8', '출시 버전'] = '10.3'

# %%
iphone_df
# Out:
#                       출시일  디스플레이    메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7    2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5    3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2.5BG      10.3      No
# iPhone 8 Plus  2017-09-22    5.5    3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8    3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8    4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5    4GB  iOS 12.0     Yes

# %% [markdown]
# ### 한 행, 열을 통째로 바꾸기

# %%
iphone_df.loc['iPhone 8']
# Out:
# 출시일        2017-09-22
# 디스플레이             4.7
# 메모리             2.5BG
# 출시 버전            10.3
# Face ID            No
# Name: iPhone 8, dtype: object

# %%
iphone_df.loc['iPhone 8'] =['2016-09-22', '4.7', '2GB', 'iOS 11.0', 'No']
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8       2016-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %%
iphone_df['디스플레이']
# Out:
# iPhone 7         4.7
# iPhone 7 Plus    5.5
# iPhone 8         4.7
# iPhone 8 Plus    5.5
# iPhone X         5.8
# iPhone XS        5.8
# iPhone XS Max    6.5
# Name: 디스플레이, dtype: object

# %%
iphone_df['디스플레이'] = ['4.7 in', '5.5 in', '4.7 in', '5.5 in', '5.8 in', '5.8 in', '6.5 in']
iphone_df
# Out:
#                       출시일   디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16  4.7 in  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16  5.5 in  3GB  iOS 10.0      No
# iPhone 8       2016-09-22  4.7 in  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22  5.5 in  3GB  iOS 11.0      No
# iPhone X       2017-11-03  5.8 in  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21  5.8 in  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21  6.5 in  4GB  iOS 12.0     Yes

# %%
iphone_df['Face ID']='Yes'
iphone_df
# Out:
#                       출시일   디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16  4.7 in  2GB  iOS 10.0     Yes
# iPhone 7 Plus  2016-09-16  5.5 in  3GB  iOS 10.0     Yes
# iPhone 8       2016-09-22  4.7 in  2GB  iOS 11.0     Yes
# iPhone 8 Plus  2017-09-22  5.5 in  3GB  iOS 11.0     Yes
# iPhone X       2017-11-03  5.8 in  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21  5.8 in  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21  6.5 in  4GB  iOS 12.0     Yes

# %% [markdown]
# ## DagaFrame에 값 쓰기2
# ### 여러 행, 열을 한번에 바꾸기

# %%
# 컬럼 여러개 바꾸기 
iphone_df[['디스플레이','Face ID']]
# Out:
#                 디스플레이 Face ID
# iPhone 7       4.7 in     Yes
# iPhone 7 Plus  5.5 in     Yes
# iPhone 8       4.7 in     Yes
# iPhone 8 Plus  5.5 in     Yes
# iPhone X       5.8 in     Yes
# iPhone XS      5.8 in     Yes
# iPhone XS Max  6.5 in     Yes

# %%
iphone_df[['디스플레이','Face ID']] = 'x'

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16     x  2GB  iOS 10.0       x
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0       x
# iPhone 8       2016-09-22     x  2GB  iOS 11.0       x
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0       x
# iPhone X       2017-11-03     x  3GB  iOS 11.1       x
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
# 행 여러개 바꾸기 
iphone_df.loc[['iPhone 7', 'iPhone X']]
# Out:
#                  출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7  2016-09-16     x  2GB  iOS 10.0       x
# iPhone X  2017-11-03     x  3GB  iOS 11.1       x

# %%
iphone_df.loc[['iPhone 7', 'iPhone X']] = 'o'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                o     o    o         o       o
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0       x
# iPhone 8       2016-09-22     x  2GB  iOS 11.0       x
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0       x
# iPhone X                o     o    o         o       o
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
# 행 슬라이싱하여 범위 모두 바꾸기 
iphone_df['iPhone 7': 'iPhone X' ]
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                o     o    o         o       o
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0       x
# iPhone 8       2016-09-22     x  2GB  iOS 11.0       x
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0       x
# iPhone X                o     o    o         o       o

# %%
iphone_df['iPhone 7': 'iPhone X' ] = 'o'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                o     o    o         o       o
# iPhone 7 Plus           o     o    o         o       o
# iPhone 8                o     o    o         o       o
# iPhone 8 Plus           o     o    o         o       o
# iPhone X                o     o    o         o       o
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %% [markdown]
# ### 조건으로 인덱싱하여 한번에 바꾸기

# %%
iphone_df['디스플레이'] >5
# Out:
# iPhone 7         False
# iPhone 7 Plus     True
# iPhone 8         False
# iPhone 8 Plus     True
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: 디스플레이, dtype: bool

# %%
iphone_df.loc[iphone_df['디스플레이'] >5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc[iphone_df['디스플레이'] >5] = 'P'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus           P     P    P         P       P
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus           P     P    P         P       P
# iPhone X                P     P    P         P       P
# iPhone XS               P     P    P         P       P
# iPhone XS Max           P     P    P         P       P

# %% [markdown]
# ### 위치로 값 바꿔주기

# %%
iphone_df.iloc[[1,3], [1,4]]
# Out:
#               디스플레이 Face ID
# iPhone 7 Plus     P       P
# iPhone 8 Plus     P       P

# %%
iphone_df.iloc[[1,3], [1,4]] ='v'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus           P     v    P         P       v
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus           P     v    P         P       v
# iPhone X                P     P    P         P       P
# iPhone XS               P     P    P         P       P
# iPhone XS Max           P     P    P         P       P

# %% [markdown]
# ## DataFrame에 값 추가/삭제
# ### 새로운 행/열에 값 추가하기

# %%
# 행 추가
iphone_df.loc['iPhone XR'] =['2018-10-26', '6.1', '3GB', 'iOS 12.0.1', 'Yes']

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리       출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB    iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB    iOS 10.0      No
# iPhone 8       2017-09-22   4.7  2GB    iOS 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB    iOS 11.0      No
# iPhone X       2017-11-03   5.8  3GB    iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB    iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB    iOS 12.0     Yes
# iPhone XR      2018-10-26   6.1  3GB  iOS 12.0.1     Yes

# %%
# 열 추가
iphone_df['제조사'] = 'Apple'
iphone_df
# Out:
#                       출시일 디스플레이  메모리       출시 버전 Face ID    제조사
# iPhone 7       2016-09-16   4.7  2GB    iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB    iOS 10.0      No  Apple
# iPhone 8       2017-09-22   4.7  2GB    iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB    iOS 11.0      No  Apple
# iPhone X       2017-11-03   5.8  3GB    iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB    iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB    iOS 12.0     Yes  Apple
# iPhone XR      2018-10-26   6.1  3GB  iOS 12.0.1     Yes  Apple

# %% [markdown]
# ### 행/열 삭제하기

# %%
# 행삭제
iphone_df.drop('iPhone XR', axis = 'index', inplace=False)
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes  Apple

# %%
# inplace = 'false'로 했기 때문에 기존 iphone_df는 영향받지 않는다. 
iphone_df
# Out:
#                       출시일 디스플레이  메모리       출시 버전 Face ID    제조사
# iPhone 7       2016-09-16   4.7  2GB    iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB    iOS 10.0      No  Apple
# iPhone 8       2017-09-22   4.7  2GB    iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB    iOS 11.0      No  Apple
# iPhone X       2017-11-03   5.8  3GB    iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB    iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB    iOS 12.0     Yes  Apple
# iPhone XR      2018-10-26   6.1  3GB  iOS 12.0.1     Yes  Apple

# %%
iphone_df.drop('iPhone XR', axis = 'index', inplace=True) # inplace= True: 변경내용 반영햐여 새로 저장
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes  Apple

# %%
# 열삭제
iphone_df.drop('제조사', axis = 'columns', inplace = True)

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %%
# 여러행삭제하기 : 리스트로 행 이름 묶기
iphone_df.drop(['iPhone 7', 'iPhone 8', 'iPhone X'], axis = 'index', inplace=False)
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %%
# 위치로 인덱싱하여 삭제하기 : 인덱스 이름만 위치로 불러올수 있게 df.index활용
iphone_df.drop(iphone_df.index[[0,2,4]], axis = 'index', inplace = False)
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# ## index/column 설정하기

# %%
liverpool_df = pd.read_csv('../../../../../Downloads/liverpool.csv',index_col=0)

# %%
liverpool_df
# Out:
#                 position  born  number nationality
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %% [markdown]
# ### column 이름 바꾸기

# %%
liverpool_df.rename(columns={'position':'Position', 'born':'Born','number':'Number', 'nationality': 'Nationality'},inplace= True)

# %%
liverpool_df
# Out:
#                 Position  Born  Number Nationality
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %% [markdown]
# ###  index 명 지정하기

# %%
liverpool_df.index.name = 'Player Name'

# %%
liverpool_df
# Out:
#                 Position  Born  Number Nationality
# Player Name
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %% [markdown]
# ### index 바꾸기

# %%
liverpool_df.set_index('Number') 
# 단, 기존 인덱스 데이터는 사라진다. (inplace = True 하지 않으면, 별수를 새롭게 저장하진 않음)
# Out:
#        Position  Born Nationality
# Number
# no. 9        FW  1991      Brazil
# no. 10       FW  1992     Senegal
# no. 11       FW  1992       Egypt
# no. 12       DF  1997     England
# no. 13       GK  1992      Brazil

# %%
liverpool_df.index
# Out:
# Index(['Roberto Firmino', 'Sadio Mane', 'Mohamed Salah', 'Joe Gomez',
#        'Alisson Becker'],
#       dtype='object', name='Player Name')

# %%
liverpool_df['Player Name'] = liverpool_df.index

# %%
liverpool_df
# Out:
#                 Position  Born  Number Nationality      Player Name
# Player Name
# Roberto Firmino       FW  1991   no. 9      Brazil  Roberto Firmino
# Sadio Mane            FW  1992  no. 10     Senegal       Sadio Mane
# Mohamed Salah         FW  1992  no. 11       Egypt    Mohamed Salah
# Joe Gomez             DF  1997  no. 12     England        Joe Gomez
# Alisson Becker        GK  1992  no. 13      Brazil   Alisson Becker

# %%
liverpool_df.set_index('Number', inplace= True) 
liverpool_df
# Out:
#        Position  Born Nationality      Player Name
# Number
# no. 9        FW  1991      Brazil  Roberto Firmino
# no. 10       FW  1992     Senegal       Sadio Mane
# no. 11       FW  1992       Egypt    Mohamed Salah
# no. 12       DF  1997     England        Joe Gomez
# no. 13       GK  1992      Brazil   Alisson Becker

# %% [markdown]
# # 큰 데이터 다루기
# ## 큰 DataFrame 살펴보기

# %%
laptop_df = pd.read_csv('../../../../../Downloads/laptops.csv',index_col=0)

# %%
laptop_df
# Out:
#                   model  ram hd_type  hd_size  screen_size   price  \
# brand
# Dell   Inspiron 15-3567    4     hdd     1024         15.6   40000
# Apple       MacBook Air    8     ssd      128         13.3   55499
# Apple       MacBook Air    8     ssd      256         13.3   71500
# Apple       MacBook Pro    8     ssd      128         13.3   96890
# Apple       MacBook Pro    8     ssd      256         13.3  112666
# ...                 ...  ...     ...      ...          ...     ...
# Asus             A555LF    8     hdd     1024         15.6   39961
# Asus      X555LA-XX172D    4     hdd      500         15.6   28489
# Asus             X554LD    2     hdd      500         15.6   29199
# Asus     X550LAV-XX771D    2     hdd      500         15.6   29990
# Asus      X540LA-XX538T    4     hdd     1024         15.6   30899
#
#       processor_brand processor_model  clock_speed graphic_card_brand  \
# brand
# Dell            intel              i5          2.5              intel
# ...

# %% [markdown]
# ### head(n): 상위 n행 출력

# %%
laptop_df.head(10)
# Out:
#                         model  ram hd_type  hd_size  screen_size   price  \
# brand
# Dell         Inspiron 15-3567    4     hdd     1024         15.6   40000
# Apple             MacBook Air    8     ssd      128         13.3   55499
# Apple             MacBook Air    8     ssd      256         13.3   71500
# Apple             MacBook Pro    8     ssd      128         13.3   96890
# Apple             MacBook Pro    8     ssd      256         13.3  112666
# Apple  MacBook Pro (TouchBar)   16     ssd      512         15.0  226000
# Apple  MacBook Pro (TouchBar)   16     ssd      512         13.3  158000
# Apple                MacBook     8     ssd      256         12.0   96990
# Dell              Vostro 3468    4     hdd     1024         14.0   33225
# Dell       Inspiron 15.6 3552    4     hdd      500         15.0   21990
#
#       processor_brand processor_model  clock_speed graphic_card_brand  \
# brand
# Dell            intel              i5          2.5              intel
# ...

# %% [markdown]
# ### tail(n): 하위 n행 출력

# %%
laptop_df.tail(4)
# Out:
#                 model  ram hd_type  hd_size  screen_size  price  \
# brand
# Asus    X555LA-XX172D    4     hdd      500         15.6  28489
# Asus           X554LD    2     hdd      500         15.6  29199
# Asus   X550LAV-XX771D    2     hdd      500         15.6  29990
# Asus    X540LA-XX538T    4     hdd     1024         15.6  30899
#
#       processor_brand processor_model  clock_speed graphic_card_brand  \
# brand
# Asus            intel      i3 4th gen          1.9              intel
# Asus            intel      i3 4th gen          1.9              intel
# Asus            intel      i3 4th gen          1.7              intel
# Asus            intel      i3 5th gen          2.0              intel
#
#        graphic_card_size       os  weight comments
# brand
# Asus                 NaN    linux     2.3      NaN
# Asus                 1.0    linux     2.3      NaN
# Asus                 NaN    linux     2.5      NaN
# Asus                 NaN  windows     2.3      NaN

# %% [markdown]
# ### shape : DataFrame 크기 출력

# %%
laptop_df.shape
# Out:
# (167, 14)

# %% [markdown]
# ### columns : DataFrame 열 출력

# %%
laptop_df.columns
# Out:
# Index(['model', 'ram', 'hd_type', 'hd_size', 'screen_size', 'price',
#        'processor_brand', 'processor_model', 'clock_speed',
#        'graphic_card_brand', 'graphic_card_size', 'os', 'weight', 'comments'],
#       dtype='object')

# %% [markdown]
# ### info(): column 기본정보

# %%
laptop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 167 entries, Dell to Asus
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   model               167 non-null    object
#  1   ram                 167 non-null    int64
#  2   hd_type             167 non-null    object
#  3   hd_size             167 non-null    int64
#  4   screen_size         167 non-null    float64
#  5   price               167 non-null    int64
#  6   processor_brand     167 non-null    object
#  7   processor_model     167 non-null    object
#  8   clock_speed         166 non-null    float64
#  9   graphic_card_brand  163 non-null    object
#  10  graphic_card_size   81 non-null     float64
#  11  os                  167 non-null    object
#  12  weight              160 non-null    float64
#  13  comments            55 non-null     object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 24.6+ KB

# %% [markdown]
# ### describes(): DF의 통계정보

# %%
laptop_df.describe()
# Out:
#               ram     hd_size  screen_size          price  clock_speed  \
# count  167.000000   167.00000   167.000000     167.000000   166.000000
# mean     6.898204   768.91018    14.775210   64132.898204     2.321084
# std      3.787479   392.99080     1.376526   42797.674010     0.554187
# min      2.000000    32.00000    10.100000   13872.000000     1.100000
# 25%      4.000000   500.00000    14.000000   35457.500000     1.900000
# 50%      8.000000  1024.00000    15.600000   47990.000000     2.300000
# 75%      8.000000  1024.00000    15.600000   77494.500000     2.600000
# max     16.000000  2048.00000    17.600000  226000.000000     3.800000
#
#        graphic_card_size      weight
# count          81.000000  160.000000
# mean           52.160494    2.250812
# std           444.134142    0.648446
# min             1.000000    0.780000
# 25%             2.000000    1.900000
# 50%             2.000000    2.200000
# 75%             4.000000    2.600000
# ...

# %% [markdown]
# ### sort_values(): 행 정렬하기

# %%
laptop_df.sort_values(by = 'price', ascending=False) #inplace = True하면 저장, 반영
# Out:
#                                 model  ram hd_type  hd_size  screen_size  \
# brand
# Apple          MacBook Pro (TouchBar)   16     ssd      512         15.0
# Alienware                 15 Notebook   16     hdd     1024         15.6
# Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# Acer                      Predator 17   16     ssd      256         17.3
# Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# ...                               ...  ...     ...      ...          ...
# Acer                  Aspire ES1-523     4     hdd     1024         15.6
# Acer         A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# Acer       Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# Acer          A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# Acer                  Aspire SW3-016     2     ssd       32         10.1
#
#             price processor_brand processor_model  clock_speed  \
# brand
# ...

# %% [markdown]
# ## 큰 Series 살펴보기

# %%
laptops_df = pd.read_csv('../../../../../Downloads/laptops.csv')

# %%
laptops_df['brand']
# Out:
# 0       Dell
# 1      Apple
# 2      Apple
# 3      Apple
# 4      Apple
#        ...
# 162     Asus
# 163     Asus
# 164     Asus
# 165     Asus
# 166     Asus
# Name: brand, Length: 167, dtype: object

# %% [markdown]
# ### unique(): 고유값 확인하기

# %%
laptops_df['brand'].unique()
# Out:
# array(['Dell', 'Apple', 'Acer', 'HP', 'Lenovo', 'Alienware', 'Microsoft',
#        'Asus'], dtype=object)

# %% [markdown]
# ### value_counts(): 값 별 카운트 확인하기

# %%
laptops_df['brand'].value_counts()
# Out:
# HP           55
# Acer         35
# Dell         31
# Lenovo       18
# Asus          9
# Apple         7
# Microsoft     6
# Alienware     6
# Name: brand, dtype: int64

# %% [markdown]
# ### describe(): 시리즈 통계 요약

# %%
laptops_df['brand'].describe()
# Out:
# count     167
# unique      8
# top        HP
# freq       55
# Name: brand, dtype: object

# %% [markdown]
# ## [실습] 여행지 선정하기 1

# %%
world_cities = pd.read_csv('../../../../../Downloads/world_cities.csv', index_col= 0)
world_cities
# Out:
#     City / Urban area     Country  Population  Land area (in sqKm)
# 0        Buenos Aires   Argentina    11200000                 2266
# 1           Melbourne   Australia     3162000                 2080
# 2              Sydney   Australia     3502000                 1687
# 3            Brisbane   Australia     1508000                 1603
# 4               Perth   Australia     1177000                  964
# ..                ...         ...         ...                  ...
# 245            Canton         USA      267000                  372
# 246           Spokane         USA      335000                  371
# 247          Tashkent  Uzbekistan     2200000                  531
# 248  Ho Chi Minh City     Vietnam     4900000                  518
# 249            Harare    Zimbabwe     1750000                  712
#
# [249 rows x 4 columns]

# %% [markdown]
# ### 질문 1
# 여행을 좋아하는 익중이는 여행지를 알아보고 있습니다. 주어진 데이터에는 총 몇 개의 도시와 몇 개의 나라가 있는지 알아맞혀 보세요.
#
# 답안은 도시/나라 형식으로 숫자만 입력해 주세요. (예시: 156/77)

# %%
# describe
world_cities.iloc[:,0:2].describe()
# Out:
#        City / Urban area Country
# count                249     249
# unique               249      61
# top              Bangkok     USA
# freq                   1     105

# %%
#nunique
print(world_cities['City / Urban area'].nunique())
print(world_cities['Country'].nunique())
# Out:
# 249
# 61

# %%
#unique
print(world_cities['City / Urban area'].unique().shape)
print(world_cities['Country'].unique().shape)
# Out:
# (249,)
# (61,)

# %%
#value_counts
print(world_cities['City / Urban area'].value_counts().shape)
print(world_cities['Country'].value_counts().shape)
# Out:
# (249,)
# (61,)

# %% [markdown]
# ### 질문2
# 사람 만나기를 좋아하는 익중이는 가장 사람이 붐비는 도시로 여행을 가기로 마음 먹었습니다. 주어진 데이터에서, 인구 밀도(명/sqKm) 가 10000 이 넘는 도시는 총 몇 개인지 알아보세요.
#
# 참고로 인구 밀도는 인구 수 / 땅의 면적 (in sqKm) 로 구할 수 있습니다.
#
# 답안은 숫자로만 입력해 주세요. (예시: 24)

# %%
world_cities["Density"] = world_cities['Population']/world_cities['Land area (in sqKm)']

# %%
world_cities[world_cities["Density"] > 10000].info() #19
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 32 to 129
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City / Urban area    19 non-null     object
#  1   Country              19 non-null     object
#  2   Population           19 non-null     int64
#  3   Land area (in sqKm)  19 non-null     int64
#  4   Density              19 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 912.0+ bytes

# %% [markdown]
# ### 질문3
# 이번에는 인구 밀도가 가장 높은 도시를 찾아봅시다.
#
# 답안은 데이터에 적힌 이름을 그대로 입력해 주세요. (예시: Seoul)

# %%
world_cities.sort_values(by="Density", ascending= False) #Mumbai
# Out:
#     City / Urban area   Country  Population  Land area (in sqKm)       Density
# 75             Mumbai     India    14350000                  484  29648.760331
# 74            Kolkata     India    12700000                  531  23917.137476
# 101           Karachi  Pakistan     9800000                  518  18918.918919
# 99              Lagos   Nigeria    13400000                  738  18157.181572
# 34           Shenzhen     China     8000000                  466  17167.381974
# ..                ...       ...         ...                  ...           ...
# 195       Chattanooga       USA      344000                  751    458.055925
# 224         Asheville       USA      222000                  536    414.179104
# 57                Pau    France      181000                  450    402.222222
# 221           Hickory       USA      188000                  546    344.322344
# 197   Barnstable Town       USA      244000                  741    329.284750
#
# [249 rows x 5 columns]

# %% [markdown]
# ## [실습] 여행지 선정하기2
# 익중이는 누나에게 여행지를 추천 받으려고 합니다.
# 그런데 나라 이름이 기억나지 않고, 이 데이터에 4개의 도시가 나왔다는 것만 기억이 난다고 하네요.
# 이 나라는 무엇일까요?
#
# 답안은 데이터에 적힌 이름 그대로 적어 주세요. (예시: France)

# %%
city_counts = world_cities['Country'].value_counts()
city_counts[city_counts==4]
# Out:
# Italy    4
# Name: Country, dtype: int64
